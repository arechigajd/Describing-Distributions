# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
data = 'Data/data.csv'

# %%
med_df = pd.read_csv(data)
med_df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
col = 'VitD_levels'
feat = med_df[col]
mean = feat.mean()
median = feat.median()
std = feat.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(9,5))
sns.histplot(feat, ax = ax, stat='probability', kde = True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(med_df['VitD_levels'], fisher = False)
print(kurt)
# Out:
# 3.013147515833447

# %% [markdown]
# 1. Is it Discrete or Continuous?
#
# This feature is continuous because the histogram bars do not have any gaps in between them.
#
# 2. Does it have a skew? If so, which direction (+/-)
#
# The mean is slightly smaller than the median. This is an indicator of a negatively skewed distribution.
#
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# Using the pearson calculation, where Mesokurtic (Kurtosis ~3), Leptokurtic (Kurtosis >3), and Platykurtic (Kurtosis < 3), though slightly, Leptokurtic is displayed at 3.01. This indicates the values cluster at the peak of the distribution. This is considered a positive Kurtosis.

# %%
col = 'Doc_visits'
feat = med_df[col]
mean = feat.mean()
median = feat.median()
std = feat.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(9,5))
sns.histplot(feat, ax = ax, stat='probability', kde = True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt1 = stats.kurtosis(med_df['Doc_visits'], fisher = False)
print(kurt1)
# Out:
# 2.9919958083381206

# %% [markdown]
# 1. Is it Discrete or Continuous?
#
# This feature is discrete because the histogram bars have gaps in between them.
#
# 2. Does it have a skew? If so, which direction (+/-)
#
# The mean in this feature is also slightly smaller than the median. This, again, is an indicator of a negatively skewed distribution.
#
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# Using the pearson calculation as mentioned above, Playtykurtic is displayed at 2.99 with this feature. This indicates the values cluster in the tails of the distribution. This is considered a negative Kurtosis.

# %%
col = 'TotalCharge'
feat = med_df[col]
mean = feat.mean()
median = feat.median()
std = feat.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(9,5))
sns.histplot(feat, ax = ax, stat='probability', kde = True)
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)
ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt2 = stats.kurtosis(med_df['TotalCharge'], fisher = False)
print(kurt2)
# Out:
# 3.2650077463439384

# %% [markdown]
# 1. Is it Discrete or Continuous?
#
# This feature is also continuous because the histogram bars do not have any gaps in between them.
#
# 2. Does it have a skew? If so, which direction (+/-)
#
# The mean is smaller than the median. This is an indicator of a negatively skewed distribution.
#
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# Using the pearson calculation, Leptokurtic is displayed at 3.26. This indicates the values cluster at the peak of the distribution. This is considered a positive Kurtosis.
